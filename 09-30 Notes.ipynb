# %%
import numpy as np

# %%
a=np.zeros(2)
print(a)
# Out:
# [0. 0.]

# %%
a+1
# Out:
# array([1., 1.])

# %%
t=np.linspace(1,7,16)
print(t)
import matplotlib.pyplot as plt
plt.plot(t,9.81*t)
# Out:
# [1.  1.4 1.8 2.2 2.6 3.  3.4 3.8 4.2 4.6 5.  5.4 5.8 6.2 6.6 7. ]
